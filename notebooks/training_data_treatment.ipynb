# %% [markdown]
# # Training data treatment for drift analysis

# %%
import sys
import os

# On remonte à la racine du projet
root_path = os.path.abspath(os.path.join(os.getcwd(), "..")) # Si ton notebook est dans un sous-dossier
# ou simplement os.getcwd() si ton notebook est à la racine
if root_path not in sys.path:
    sys.path.append(root_path)

import pandas as pd

from config.config import BASE_DIR

# %% [markdown]
# ## Récupération des données entrées P6

# %%
df = pd.read_parquet(BASE_DIR / "data" / "external" / "kaggle_master_dataset.parquet")

# %%
df.shape
# Out:
# (356193, 581)

# %%
df_normal = df.sample(1000, random_state=42)
df_drifted = df.sample(300, random_state=43)

# %% [markdown]
# ## Récupération de la signature du modèle déployé

# %%
import requests
try:
    response = requests.get("http://localhost:8000/model_signature")
    data = response.json()
    columns = data['columns']
    print(f"Retrieved {len(columns)} columns")
except Exception as e:
    print(f"error : {e}")
# Out:
# Retrieved 15 columns

# %%
feature_names = [col['name'] for col in columns]
feature_names
# Out:
# ['FE_EXT_SOURCE_MEAN',
#  'BURO_MONTHS_BALANCE_SIZE_MEAN',
#  'CODE_GENDER',
#  'INSTAL_DPD_MEAN',
#  'BURO_MONTHS_BALANCE_MAX_MIN',
#  'FE_GOODS_CREDIT_RATE',
#  'APPROVED_CNT_PAYMENT_MEAN',
#  'YEARS_BIRTH',
#  'YEARS_EMPLOYED',
#  'AMT_ANNUITY',
#  'NAME_FAMILY_STATUS_Married',
#  'INSTAL_AMT_PAYMENT_SUM',
#  'FE_EXT_SOURCE_MIN',
#  'PREV_CNT_PAYMENT_MEAN',
#  'FE_EXT_SOURCE_MAX']

# %% [markdown]
# # Création du df Normal et Drifted

# %%
df_normal = df_normal[feature_names]
df_drifted = df_drifted[feature_names]

# %%
df_normal.head()
# Out:
#         FE_EXT_SOURCE_MEAN  BURO_MONTHS_BALANCE_SIZE_MEAN  CODE_GENDER  \
# 83482             0.386921                            0.0            1
# 118211            0.298974                           24.0            1
# 253872            0.276205                            0.0            1
# 242553            0.048021                            0.0            0
# 118923            0.721261                            0.0            1
#
#         INSTAL_DPD_MEAN  BURO_MONTHS_BALANCE_MAX_MIN  FE_GOODS_CREDIT_RATE  \
# 83482          0.000000                          0.0              1.000000
# 118211         0.000000                          0.0              1.237600
# 253872         0.250000                          0.0              1.198000
# 242553         0.000000                          0.0              1.000000
# 118923         1.169231                          0.0              1.043562
#
#         APPROVED_CNT_PAYMENT_MEAN  YEARS_BIRTH  YEARS_EMPLOYED  AMT_ANNUITY  \
# 83482                   18.000000           50               0       6421.5
# 118211                  12.000000           23               2       8748.0
# 253872                  12.000000           40               8      20488.5
# 242553                  12.000000           22               0      42853.5
# 118923                   5.333333           54               4      63463.5
#
#         NAME_FAMILY_STATUS_Married  INSTAL_AMT_PAYMENT_SUM  FE_EXT_SOURCE_MIN  \
# 83482                        False              104419.080           0.199771
# 118211                       False              104536.620           0.199665
# 253872                        True               53162.235           0.004123
# 242553                       False               53292.735           0.048021
# 118923                        True             1256113.035           0.684128
#
#         PREV_CNT_PAYMENT_MEAN  FE_EXT_SOURCE_MAX
# 83482               18.000000           0.574070
# 118211              12.000000           0.366006
# 253872              12.000000           0.548286
# 242553              12.000000           0.048021
# 118923               5.333333           0.758393

# %%
df_drifted.head()
# Out:
#         FE_EXT_SOURCE_MEAN  BURO_MONTHS_BALANCE_SIZE_MEAN  CODE_GENDER  \
# 341678            0.452871                      36.000000            1
# 348293            0.635872                      30.666667            1
# 210104            0.446940                       0.000000            1
# 291101            0.371930                       0.000000            1
# 353140            0.627556                      17.444444            1
#
#         INSTAL_DPD_MEAN  BURO_MONTHS_BALANCE_MAX_MIN  FE_GOODS_CREDIT_RATE  \
# 341678         0.041096                          0.0              1.000000
# 348293         0.000000                          0.0              1.257400
# 210104         0.000000                          0.0              1.211200
# 291101         0.000000                          0.0              1.118802
# 353140         0.000000                          0.0              1.000000
#
#         APPROVED_CNT_PAYMENT_MEAN  YEARS_BIRTH  YEARS_EMPLOYED  AMT_ANNUITY  \
# 341678                      10.75           28               0       7560.0
# 348293                      10.00           35               8      26298.0
# 210104                      24.00           37               7      25407.0
# 291101                      15.00           31               0      24592.5
# 353140                      17.00           61               0       6673.5
#
#         NAME_FAMILY_STATUS_Married  INSTAL_AMT_PAYMENT_SUM  FE_EXT_SOURCE_MIN  \
# 341678                       False              725286.690           0.157863
# 348293                       False              461560.680           0.540206
# 210104                        True               98790.120           0.210980
# 291101                       False              436123.935           0.220095
# 353140                        True              137248.785           0.410103
#
#         PREV_CNT_PAYMENT_MEAN  FE_EXT_SOURCE_MAX
# 341678                  10.75           0.692559
# 348293                  10.00           0.741107
# 210104                  24.00           0.652897
# 291101                  15.00           0.523765
# 353140                  17.00           0.897654

# %%
df_drifted['AMT_ANNUITY'] = df["AMT_ANNUITY"] * 2

# %%
df_drifted.head()
# Out:
#         FE_EXT_SOURCE_MEAN  BURO_MONTHS_BALANCE_SIZE_MEAN  CODE_GENDER  \
# 341678            0.452871                      36.000000            1
# 348293            0.635872                      30.666667            1
# 210104            0.446940                       0.000000            1
# 291101            0.371930                       0.000000            1
# 353140            0.627556                      17.444444            1
#
#         INSTAL_DPD_MEAN  BURO_MONTHS_BALANCE_MAX_MIN  FE_GOODS_CREDIT_RATE  \
# 341678         0.041096                          0.0              1.000000
# 348293         0.000000                          0.0              1.257400
# 210104         0.000000                          0.0              1.211200
# 291101         0.000000                          0.0              1.118802
# 353140         0.000000                          0.0              1.000000
#
#         APPROVED_CNT_PAYMENT_MEAN  YEARS_BIRTH  YEARS_EMPLOYED  AMT_ANNUITY  \
# 341678                      10.75           28               0      15120.0
# 348293                      10.00           35               8      52596.0
# 210104                      24.00           37               7      50814.0
# 291101                      15.00           31               0      49185.0
# 353140                      17.00           61               0      13347.0
#
#         NAME_FAMILY_STATUS_Married  INSTAL_AMT_PAYMENT_SUM  FE_EXT_SOURCE_MIN  \
# 341678                       False              725286.690           0.157863
# 348293                       False              461560.680           0.540206
# 210104                        True               98790.120           0.210980
# 291101                       False              436123.935           0.220095
# 353140                        True              137248.785           0.410103
#
#         PREV_CNT_PAYMENT_MEAN  FE_EXT_SOURCE_MAX
# 341678                  10.75           0.692559
# 348293                  10.00           0.741107
# 210104                  24.00           0.652897
# 291101                  15.00           0.523765
# 353140                  17.00           0.897654

# %% [markdown]
# ## Enregistrement des df en CSV

# %%
df_normal.to_csv(BASE_DIR / "data" / 'processed' / "normal_sample.csv")

# %%
df_drifted.to_csv(BASE_DIR / "data" / 'processed' / "drifted_sample.csv")

# %% [markdown]
# ## Appels API sur les lignes du normal puis du drifted

# %%
import time
import random
import requests

def api_calls(dataframe, limit=5):
    """
    Envoie des requêtes POST à l'API pour un échantillon de données.
    """
    print(f"🚀 Démarrage des appels API pour {limit} lignes...")
    
    for index, row in dataframe.head(limit).iterrows():
        # Conversion de la ligne en dictionnaire pour le JSON
        payload = row.to_dict()

        # Petit délai aléatoire (simule un trafic réel)
        tempo = random.uniform(0.5, 2.0)
        time.sleep(tempo)

        try:
            # L'endpoint /individual_score attend une requête POST
            response = requests.post("http://localhost:8000/individual_score", json=payload)
            
            if response.status_code == 200:
                res_data = response.json()
                # Correction : la clé retournée par l'API est 'score' et non 'probability'
                score = res_data.get('score')
                decision = res_data.get('decision')
                print(f"✅ Index {index} : Score={score:.3f}, Décision={decision}")
            else:
                print(f"❌ Index {index} : Erreur {response.status_code} - {response.text}")
                
        except Exception as e:
            print(f"⚠️ Index {index} : Erreur lors de l'appel : {e}")

# On peut maintenant tester la fonction
# api_calls(df_normal, limit=1000)

# %%
api_calls(df_drifted, limit=300)
# Out:
# 🚀 Démarrage des appels API pour 300 lignes...
# ✅ Index 341678 : Score=0.141, Décision=Accordé
# ✅ Index 348293 : Score=0.112, Décision=Accordé
# ✅ Index 210104 : Score=0.600, Décision=Accordé
# ✅ Index 291101 : Score=0.545, Décision=Accordé
# ✅ Index 353140 : Score=0.076, Décision=Accordé
# ✅ Index 173167 : Score=0.310, Décision=Accordé
# ✅ Index 248103 : Score=0.208, Décision=Accordé
# ✅ Index 250746 : Score=0.213, Décision=Accordé
# ✅ Index 243362 : Score=0.453, Décision=Accordé
# ✅ Index 123988 : Score=0.408, Décision=Accordé
# ✅ Index 311681 : Score=0.110, Décision=Accordé
# ✅ Index 154365 : Score=0.189, Décision=Accordé
# ✅ Index 325149 : Score=0.135, Décision=Accordé
# ✅ Index 102804 : Score=0.670, Décision=Accordé
# ✅ Index 40868 : Score=0.194, Décision=Accordé
# ✅ Index 189223 : Score=0.188, Décision=Accordé
# ✅ Index 247288 : Score=0.209, Décision=Accordé
# ✅ Index 183855 : Score=0.088, Décision=Accordé
# ✅ Index 232734 : Score=0.510, Décision=Accordé
# ✅ Index 187255 : Score=0.604, Décision=Accordé
# ✅ Index 188223 : Score=0.264, Décision=Accordé
# ✅ Index 208710 : Score=0.265, Décision=Accordé
# ✅ Index 57342 : Score=0.204, Décision=Accordé
# ✅ Index 3266 : Score=0.487, Décision=Accordé
# ✅ Index 329595 : Score=0.136, Décision=Accordé
# ✅ Index 57734 : Score=0.320, Décision=Accordé
# ✅ Index 327425 : Score=0.178, Décision=Accordé
# ✅ Index 263580 : Score=0.350, Décision=Accordé
# ✅ Index 190502 : Score=0.173, Décision=Accordé
# ✅ Index 284943 : Score=0.436, Décision=Accordé
# ✅ Index 140271 : Score=0.236, Décision=Accordé
# ✅ Index 277679 : Score=0.325, Décision=Accordé
# ✅ Index 62918 : Score=0.166, Décision=Accordé
# ✅ Index 51466 : Score=0.438, Décision=Accordé
# ✅ Index 248270 : Score=0.620, Décision=Accordé
# ✅ Index 145928 : Score=0.196, Décision=Accordé
# ✅ Index 167139 : Score=0.433, Décision=Accordé
# ✅ Index 85296 : Score=0.616, Décision=Accordé
# ✅ Index 237386 : Score=0.727, Décision=Refusé
# ✅ Index 151528 : Score=0.809, Décision=Refusé
# ✅ Index 182029 : Score=0.268, Décision=Accordé
# ✅ Index 103727 : Score=0.127, Décision=Accordé
# ✅ Index 133293 : Score=0.693, Décision=Accordé
# ✅ Index 289314 : Score=0.125, Décision=Accordé
# ✅ Index 27155 : Score=0.462, Décision=Accordé
# ✅ Index 295635 : Score=0.047, Décision=Accordé
# ✅ Index 55189 : Score=0.935, Décision=Refusé
# ✅ Index 68912 : Score=0.319, Décision=Accordé
# ✅ Index 28995 : Score=0.392, Décision=Accordé
# ✅ Index 200681 : Score=0.242, Décision=Accordé
# ✅ Index 83261 : Score=0.729, Décision=Refusé
# ✅ Index 96510 : Score=0.373, Décision=Accordé
# ✅ Index 121049 : Score=0.439, Décision=Accordé
# ✅ Index 99500 : Score=0.359, Décision=Accordé
# ✅ Index 58180 : Score=0.300, Décision=Accordé
# ✅ Index 194511 : Score=0.177, Décision=Accordé
# ✅ Index 28486 : Score=0.768, Décision=Refusé
# ✅ Index 227357 : Score=0.595, Décision=Accordé
# ✅ Index 184269 : Score=0.218, Décision=Accordé
# ✅ Index 282956 : Score=0.099, Décision=Accordé
# ✅ Index 107801 : Score=0.441, Décision=Accordé
# ✅ Index 53790 : Score=0.646, Décision=Accordé
# ✅ Index 19420 : Score=0.446, Décision=Accordé
# ✅ Index 208301 : Score=0.357, Décision=Accordé
# ✅ Index 144125 : Score=0.166, Décision=Accordé
# ✅ Index 133801 : Score=0.436, Décision=Accordé
# ✅ Index 68411 : Score=0.150, Décision=Accordé
# ✅ Index 287174 : Score=0.472, Décision=Accordé
# ✅ Index 171442 : Score=0.286, Décision=Accordé
# ✅ Index 243801 : Score=0.396, Décision=Accordé
# ✅ Index 165327 : Score=0.842, Décision=Refusé
# ✅ Index 36148 : Score=0.476, Décision=Accordé
# ✅ Index 303426 : Score=0.311, Décision=Accordé
# ✅ Index 305872 : Score=0.585, Décision=Accordé
# ✅ Index 82823 : Score=0.389, Décision=Accordé
# ✅ Index 170687 : Score=0.824, Décision=Refusé
# ✅ Index 249238 : Score=0.089, Décision=Accordé
# ✅ Index 268064 : Score=0.201, Décision=Accordé
# ✅ Index 128759 : Score=0.244, Décision=Accordé
# ✅ Index 74410 : Score=0.151, Décision=Accordé
# ✅ Index 124212 : Score=0.561, Décision=Accordé
# ✅ Index 114407 : Score=0.157, Décision=Accordé
# ✅ Index 193294 : Score=0.206, Décision=Accordé
# ✅ Index 88683 : Score=0.695, Décision=Accordé
# ✅ Index 89253 : Score=0.334, Décision=Accordé
# ✅ Index 30381 : Score=0.655, Décision=Accordé
# ✅ Index 167206 : Score=0.494, Décision=Accordé
# ✅ Index 40616 : Score=0.187, Décision=Accordé
# ✅ Index 186334 : Score=0.285, Décision=Accordé
# ✅ Index 242282 : Score=0.454, Décision=Accordé
# ✅ Index 215790 : Score=0.706, Décision=Refusé
# ✅ Index 292191 : Score=0.317, Décision=Accordé
# ✅ Index 350811 : Score=0.099, Décision=Accordé
# ✅ Index 336753 : Score=0.020, Décision=Accordé
# ✅ Index 328897 : Score=0.521, Décision=Accordé
# ✅ Index 197114 : Score=0.122, Décision=Accordé
# ✅ Index 43383 : Score=0.591, Décision=Accordé
# ✅ Index 315622 : Score=0.204, Décision=Accordé
# ✅ Index 15496 : Score=0.623, Décision=Accordé
# ✅ Index 296048 : Score=0.224, Décision=Accordé
# ✅ Index 310200 : Score=0.228, Décision=Accordé
# ✅ Index 341977 : Score=0.363, Décision=Accordé
# ✅ Index 273544 : Score=0.587, Décision=Accordé
# ✅ Index 49912 : Score=0.366, Décision=Accordé
# ✅ Index 157368 : Score=0.288, Décision=Accordé
# ✅ Index 149314 : Score=0.460, Décision=Accordé
# ✅ Index 247330 : Score=0.296, Décision=Accordé
# ✅ Index 318556 : Score=0.670, Décision=Accordé
# ✅ Index 7414 : Score=0.336, Décision=Accordé
# ✅ Index 204820 : Score=0.047, Décision=Accordé
# ✅ Index 345009 : Score=0.071, Décision=Accordé
# ✅ Index 23439 : Score=0.329, Décision=Accordé
# ✅ Index 284221 : Score=0.230, Décision=Accordé
# ✅ Index 308504 : Score=0.064, Décision=Accordé
# ✅ Index 285665 : Score=0.343, Décision=Accordé
# ✅ Index 75547 : Score=0.858, Décision=Refusé
# ✅ Index 163405 : Score=0.270, Décision=Accordé
# ✅ Index 310113 : Score=0.543, Décision=Accordé
# ✅ Index 23978 : Score=0.199, Décision=Accordé
# ✅ Index 144457 : Score=0.801, Décision=Refusé
# ✅ Index 125271 : Score=0.223, Décision=Accordé
# ✅ Index 293957 : Score=0.256, Décision=Accordé
# ✅ Index 157217 : Score=0.819, Décision=Refusé
# ✅ Index 21774 : Score=0.660, Décision=Accordé
# ✅ Index 233203 : Score=0.187, Décision=Accordé
# ✅ Index 298463 : Score=0.865, Décision=Refusé
# ✅ Index 216986 : Score=0.507, Décision=Accordé
# ✅ Index 314521 : Score=0.853, Décision=Refusé
# ✅ Index 155356 : Score=0.045, Décision=Accordé
# ✅ Index 21093 : Score=0.380, Décision=Accordé
# ✅ Index 107073 : Score=0.391, Décision=Accordé
# ✅ Index 22208 : Score=0.177, Décision=Accordé
# ✅ Index 144314 : Score=0.080, Décision=Accordé
# ✅ Index 35455 : Score=0.242, Décision=Accordé
# ✅ Index 105693 : Score=0.477, Décision=Accordé
# ✅ Index 257547 : Score=0.342, Décision=Accordé
# ✅ Index 166459 : Score=0.335, Décision=Accordé
# ✅ Index 59790 : Score=0.167, Décision=Accordé
# ✅ Index 171328 : Score=0.577, Décision=Accordé
# ✅ Index 39186 : Score=0.295, Décision=Accordé
# ✅ Index 356136 : Score=0.149, Décision=Accordé
# ✅ Index 196673 : Score=0.572, Décision=Accordé
# ✅ Index 33548 : Score=0.521, Décision=Accordé
# ✅ Index 323125 : Score=0.142, Décision=Accordé
# ✅ Index 235711 : Score=0.202, Décision=Accordé
# ✅ Index 166227 : Score=0.621, Décision=Accordé
# ✅ Index 46591 : Score=0.188, Décision=Accordé
# ✅ Index 97516 : Score=0.166, Décision=Accordé
# ✅ Index 2055 : Score=0.855, Décision=Refusé
# ✅ Index 93300 : Score=0.186, Décision=Accordé
# ✅ Index 235793 : Score=0.658, Décision=Accordé
# ✅ Index 109050 : Score=0.596, Décision=Accordé
# ✅ Index 134281 : Score=0.544, Décision=Accordé
# ✅ Index 259344 : Score=0.822, Décision=Refusé
# ✅ Index 31339 : Score=0.649, Décision=Accordé
# ✅ Index 342650 : Score=0.107, Décision=Accordé
# ✅ Index 333908 : Score=0.370, Décision=Accordé
# ✅ Index 262784 : Score=0.334, Décision=Accordé
# ✅ Index 296915 : Score=0.270, Décision=Accordé
# ✅ Index 52607 : Score=0.584, Décision=Accordé
# ✅ Index 215179 : Score=0.260, Décision=Accordé
# ✅ Index 197378 : Score=0.162, Décision=Accordé
# ✅ Index 202581 : Score=0.426, Décision=Accordé
# ✅ Index 34734 : Score=0.352, Décision=Accordé
# ✅ Index 134904 : Score=0.794, Décision=Refusé
# ✅ Index 121576 : Score=0.445, Décision=Accordé
# ✅ Index 269209 : Score=0.412, Décision=Accordé
# ✅ Index 94691 : Score=0.337, Décision=Accordé
# ✅ Index 238460 : Score=0.403, Décision=Accordé
# ✅ Index 232660 : Score=0.073, Décision=Accordé
# ✅ Index 244919 : Score=0.334, Décision=Accordé
# ✅ Index 23604 : Score=0.551, Décision=Accordé
# ✅ Index 333404 : Score=0.376, Décision=Accordé
# ✅ Index 282666 : Score=0.329, Décision=Accordé
# ✅ Index 183506 : Score=0.468, Décision=Accordé
# ✅ Index 157094 : Score=0.851, Décision=Refusé
# ✅ Index 12265 : Score=0.667, Décision=Accordé
# ✅ Index 251966 : Score=0.151, Décision=Accordé
# ✅ Index 88451 : Score=0.189, Décision=Accordé
# ✅ Index 122103 : Score=0.444, Décision=Accordé
# ✅ Index 106343 : Score=0.219, Décision=Accordé
# ✅ Index 291252 : Score=0.629, Décision=Accordé
# ✅ Index 112300 : Score=0.268, Décision=Accordé
# ✅ Index 353233 : Score=0.750, Décision=Refusé
# ✅ Index 158097 : Score=0.413, Décision=Accordé
# ✅ Index 137518 : Score=0.165, Décision=Accordé
# ✅ Index 238704 : Score=0.113, Décision=Accordé
# ✅ Index 166505 : Score=0.313, Décision=Accordé
# ✅ Index 269484 : Score=0.442, Décision=Accordé
# ✅ Index 312765 : Score=0.267, Décision=Accordé
# ✅ Index 232801 : Score=0.167, Décision=Accordé
# ✅ Index 118066 : Score=0.222, Décision=Accordé
# ✅ Index 192834 : Score=0.804, Décision=Refusé
# ✅ Index 80820 : Score=0.062, Décision=Accordé
# ✅ Index 352102 : Score=0.378, Décision=Accordé
# ✅ Index 87707 : Score=0.300, Décision=Accordé
# ✅ Index 355850 : Score=0.107, Décision=Accordé
# ✅ Index 170108 : Score=0.457, Décision=Accordé
# ✅ Index 338869 : Score=0.392, Décision=Accordé
# ✅ Index 109902 : Score=0.788, Décision=Refusé
# ✅ Index 65678 : Score=0.793, Décision=Refusé
# ✅ Index 215874 : Score=0.219, Décision=Accordé
# ✅ Index 311717 : Score=0.158, Décision=Accordé
# ✅ Index 266212 : Score=0.263, Décision=Accordé
# ✅ Index 235730 : Score=0.128, Décision=Accordé
# ✅ Index 86191 : Score=0.686, Décision=Accordé
# ✅ Index 325268 : Score=0.158, Décision=Accordé
# ✅ Index 67989 : Score=0.070, Décision=Accordé
# ✅ Index 88635 : Score=0.445, Décision=Accordé
# ✅ Index 299860 : Score=0.172, Décision=Accordé
# ✅ Index 267126 : Score=0.296, Décision=Accordé
# ✅ Index 42021 : Score=0.652, Décision=Accordé
# ✅ Index 204239 : Score=0.236, Décision=Accordé
# ✅ Index 1709 : Score=0.711, Décision=Refusé
# ✅ Index 25492 : Score=0.688, Décision=Accordé
# ✅ Index 51915 : Score=0.358, Décision=Accordé
# ✅ Index 11160 : Score=0.130, Décision=Accordé
# ✅ Index 224906 : Score=0.718, Décision=Refusé
# ✅ Index 62396 : Score=0.443, Décision=Accordé
# ✅ Index 107684 : Score=0.049, Décision=Accordé
# ✅ Index 72046 : Score=0.722, Décision=Refusé
# ✅ Index 69126 : Score=0.618, Décision=Accordé
# ✅ Index 143391 : Score=0.044, Décision=Accordé
# ✅ Index 160480 : Score=0.167, Décision=Accordé
# ✅ Index 88060 : Score=0.642, Décision=Accordé
# ✅ Index 124400 : Score=0.330, Décision=Accordé
# ✅ Index 39168 : Score=0.326, Décision=Accordé
# ✅ Index 23373 : Score=0.203, Décision=Accordé
# ✅ Index 51418 : Score=0.779, Décision=Refusé
# ✅ Index 149419 : Score=0.044, Décision=Accordé
# ✅ Index 207551 : Score=0.753, Décision=Refusé
# ✅ Index 220958 : Score=0.459, Décision=Accordé
# ✅ Index 262946 : Score=0.299, Décision=Accordé
# ✅ Index 170839 : Score=0.102, Décision=Accordé
# ✅ Index 154072 : Score=0.801, Décision=Refusé
# ✅ Index 245235 : Score=0.865, Décision=Refusé
# ✅ Index 244284 : Score=0.645, Décision=Accordé
# ✅ Index 347058 : Score=0.076, Décision=Accordé
# ✅ Index 347891 : Score=0.257, Décision=Accordé
# ✅ Index 306325 : Score=0.621, Décision=Accordé
# ✅ Index 45233 : Score=0.655, Décision=Accordé
# ✅ Index 82572 : Score=0.128, Décision=Accordé
# ✅ Index 102103 : Score=0.174, Décision=Accordé
# ✅ Index 71197 : Score=0.238, Décision=Accordé
# ✅ Index 313676 : Score=0.177, Décision=Accordé
# ✅ Index 302339 : Score=0.136, Décision=Accordé
# ✅ Index 160454 : Score=0.358, Décision=Accordé
# ✅ Index 8016 : Score=0.370, Décision=Accordé
# ✅ Index 324984 : Score=0.415, Décision=Accordé
# ✅ Index 156349 : Score=0.554, Décision=Accordé
# ✅ Index 227585 : Score=0.339, Décision=Accordé
# ✅ Index 173909 : Score=0.261, Décision=Accordé
# ✅ Index 142318 : Score=0.490, Décision=Accordé
# ✅ Index 139945 : Score=0.606, Décision=Accordé
# ✅ Index 278969 : Score=0.454, Décision=Accordé
# ✅ Index 163266 : Score=0.502, Décision=Accordé
# ✅ Index 330023 : Score=0.083, Décision=Accordé
# ✅ Index 211451 : Score=0.783, Décision=Refusé
# ✅ Index 211390 : Score=0.307, Décision=Accordé
# ✅ Index 314167 : Score=0.268, Décision=Accordé
# ✅ Index 83193 : Score=0.158, Décision=Accordé
# ✅ Index 303001 : Score=0.228, Décision=Accordé
# ✅ Index 169784 : Score=0.800, Décision=Refusé
# ✅ Index 103541 : Score=0.589, Décision=Accordé
# ✅ Index 273061 : Score=0.334, Décision=Accordé
# ✅ Index 209446 : Score=0.372, Décision=Accordé
# ✅ Index 174867 : Score=0.147, Décision=Accordé
# ✅ Index 92401 : Score=0.700, Décision=Refusé
# ✅ Index 21986 : Score=0.798, Décision=Refusé
# ✅ Index 21488 : Score=0.398, Décision=Accordé
# ✅ Index 15654 : Score=0.530, Décision=Accordé
# ✅ Index 266343 : Score=0.535, Décision=Accordé
# ✅ Index 104813 : Score=0.299, Décision=Accordé
# ✅ Index 306567 : Score=0.301, Décision=Accordé
# ✅ Index 306524 : Score=0.459, Décision=Accordé
# ✅ Index 202119 : Score=0.831, Décision=Refusé
# ✅ Index 127361 : Score=0.313, Décision=Accordé
# ✅ Index 7724 : Score=0.212, Décision=Accordé
# ✅ Index 37245 : Score=0.067, Décision=Accordé
# ✅ Index 143681 : Score=0.507, Décision=Accordé
# ✅ Index 205498 : Score=0.563, Décision=Accordé
# ✅ Index 153873 : Score=0.288, Décision=Accordé
# ✅ Index 298854 : Score=0.243, Décision=Accordé
# ✅ Index 217499 : Score=0.755, Décision=Refusé
# ✅ Index 203712 : Score=0.098, Décision=Accordé
# ✅ Index 196739 : Score=0.500, Décision=Accordé
# ✅ Index 317484 : Score=0.045, Décision=Accordé
# ✅ Index 197275 : Score=0.271, Décision=Accordé
# ✅ Index 100806 : Score=0.517, Décision=Accordé
# ✅ Index 308070 : Score=0.245, Décision=Accordé
# ✅ Index 286391 : Score=0.098, Décision=Accordé
# ✅ Index 189755 : Score=0.692, Décision=Accordé
# ✅ Index 116102 : Score=0.691, Décision=Accordé
# ✅ Index 54448 : Score=0.264, Décision=Accordé
# ✅ Index 109711 : Score=0.662, Décision=Accordé
# ✅ Index 32795 : Score=0.880, Décision=Refusé
# ✅ Index 194304 : Score=0.143, Décision=Accordé
# ✅ Index 172542 : Score=0.469, Décision=Accordé
# ✅ Index 210351 : Score=0.223, Décision=Accordé
# ✅ Index 338613 : Score=0.044, Décision=Accordé
